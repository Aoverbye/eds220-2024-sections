# %% [markdown]
# # EDS220 Week 1 Discussion Section: Preliminary data exploration with pandas
#
# [Discussion section website](https://meds-eds-220.github.io/MEDS-eds-220-course/discussion-sections/ds1-prelim-data-exploration.html)
#
# Citation:
#
# Rachel King, Jenna Braun, Michael Westphal, & CJ Lortie. (2023). Compiled occurrence records for prey items of listed species found in California drylands with associated environmental data. Knowledge Network for Biocomplexity. doi:10.5063/F1VM49RH.

# %% [markdown]
# ## 1. Archive exploration

# %% [markdown]
# ## 2. Metadata exploration

# %%
# Loading in the library
import pandas as pd

# %%
# Reading in the data
pd.read_csv('https://knb.ecoinformatics.org/knb/d1/mn/v2/object/urn%3Auuid%3A3baf7289-bf90-4db3-ad11-58785c09b26e')
# Out:
#                         attribute  \
# 0                           class
# 1                           order
# 2                          family
# 3                           genus
# 4                         species
# 5                             lat
# 6                            long
# 7                       eventDate
# 8                             day
# 9                           month
# 10                           year
# 11                institutionCode
# 12  coordinateUncertaintyInMeters
# 13                  basisOfRecord
# 14                individualCount
# 15                     datasetKey
# 16                           bio1
# 17                          bio10
# 18                          bio11
# 19                          bio12
# 20                          bio13
# 21                          bio14
# 22                          bio15
# 23                          bio16
# 24                          bio17
# 25                          bio18
# ...

# %% [markdown]
# ## 3. Data loading

# %%
# Load data
prey = pd.read_csv('https://knb.ecoinformatics.org/knb/d1/mn/v2/object/urn%3Auuid%3A23d42528-1048-45d4-85d1-7e13b666e744')

# %%
# Checking the type of variable "prey" is
type(prey)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ## 4. Looking at our data

# %%
# View the head of the dataframe
prey.head()
# Out:
#           class        order           family          genus  \
# 0       Insecta      Odonata     Libellulidae      Sympetrum
# 1  Malacostraca      Isopoda  Armadillidiidae  Armadillidium
# 2       Insecta  Hymenoptera           Apidae         Bombus
# 3       Insecta  Hymenoptera           Apidae           Apis
# 4       Insecta    Hemiptera        Lygaeidae     Oncopeltus
#
#                  species        lat        long             eventDate   day  \
# 0    Sympetrum corruptum  37.173971 -121.856329  2020-09-29T08:24:00Z  29.0
# 1  Armadillidium vulgare  37.688580 -122.436608  2021-12-04T14:49:59Z   4.0
# 2    Bombus vosnesenskii  33.774911 -116.679713  2021-06-18T08:52:00Z  18.0
# 3         Apis mellifera  32.848001 -117.050126  2016-04-17T09:28:00Z  17.0
# 4   Oncopeltus fasciatus  32.739453 -117.133980  2019-04-06T18:44:31Z   6.0
#
#    month  ...         bio4        bio5       bio6        bio7        bio8  \
# ...

# %%
# Viewing all of the columns in the dataframe
# What option do you want to display?
# What do you want to change the option to?
pd.set_option("display.max.columns", None)

# %%
# Viewing the data again
prey.head()
prey.tail()
prey.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 111156 entries, 0 to 111155
# Data columns (total 40 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   class                          111156 non-null  object
#  1   order                          111054 non-null  object
#  2   family                         111156 non-null  object
#  3   genus                          111156 non-null  object
#  4   species                        111156 non-null  object
#  5   lat                            111156 non-null  float64
#  6   long                           111156 non-null  float64
#  7   eventDate                      111156 non-null  object
#  8   day                            110998 non-null  float64
#  9   month                          111127 non-null  float64
#  10  year                           111156 non-null  int64
#  11  institutionCode                110414 non-null  object
# ...

# %%
# Using the nunique() function
prey.nunique()
# Out:
# class                                 4
# order                                18
# family                               63
# genus                                92
# species                              97
# lat                               91909
# long                              91965
# eventDate                        102140
# day                                  31
# month                                12
# year                                 77
# institutionCode                      77
# coordinateUncertaintyInMeters      4450
# basisOfRecord                         4
# individualCount                      42
# datasetKey                           88
# ID                               111156
# bio1                              11778
# bio10                             11981
# bio11                             11803
# bio12                             12117
# bio13                             12020
# bio14                              4586
# ...

# %%
# Looking at the shape of the dataframe
prey.shape
# Out:
# (111156, 40)

# %%
# Looking at the columns of the dataframe
prey.columns
# Out:
# Index(['class', 'order', 'family', 'genus', 'species', 'lat', 'long',
#        'eventDate', 'day', 'month', 'year', 'institutionCode',
#        'coordinateUncertaintyInMeters', 'basisOfRecord', 'individualCount',
#        'datasetKey', 'ID', 'bio1', 'bio10', 'bio11', 'bio12', 'bio13', 'bio14',
#        'bio15', 'bio16', 'bio17', 'bio18', 'bio19', 'bio2', 'bio3', 'bio4',
#        'bio5', 'bio6', 'bio7', 'bio8', 'bio9', 'dist', 'dem90_hf', 'lc_class',
#        'ndvi'],
#       dtype='object')

# %%
# Rename column names
# Look into pi janitor

prey = prey.rename(columns =('institutionCode':'institution_Code', 'datasetKey':'dataset_key'))
# Out:
#   File "/tmp/ipykernel_1531564/4157683483.py", line 3
#     prey = prey.rename(columns =('institutionCode':'institution_Code', 'datasetKey':'dataset_key'))
#                                                   ^
# SyntaxError: invalid syntax
